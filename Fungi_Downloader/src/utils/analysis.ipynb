# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('../../data/fourdbs_concat/fourdbs_input_species.csv')

df
# Out:
#                     species_name  \
# 0       saccharomyces_cerevisiae
# 1             fusarium_oxysporum
# 2               candida_albicans
# 3        cryptococcus_neoformans
# 4     saccharomyces_kudriavzevii
# ...                          ...
# 2485     achaetomium_macrosporum
# 2486         acarospora_strigata
# 2487             absidia_padenii
# 2488            absidia_caerulea
# 2489         abortiporus_biennis
#
#                                        genome_file_name  \
# 0                  saccharomyces_cerevisiae_genomic.fna
# 1                        fusarium_oxysporum_genomic.fna
# 2                          candida_albicans_genomic.fna
# 3                   cryptococcus_neoformans_genomic.fna
# 4                saccharomyces_kudriavzevii_genomic.fna
# ...                                                 ...
# 2485  achaetomium_macrosporum_cbs_532_94_v1_0_genomi...
# 2486         acarospora_strigata_cbs_132363_genomic.fna
# 2487         absidia_padenii_nrrl_2977_v1_0_genomic.fna
# 2488         absidia_caerulea_nrrl1315_v1_0_genomic.fna
# 2489  abortiporus_biennis_cirm_brfm_1778_v1_0_genomi...
#
#                                         cds_file_name  \
# 0                    saccharomyces_cerevisiae_cds.fna
# 1                          fusarium_oxysporum_cds.fna
# 2                            candida_albicans_cds.fna
# 3                     cryptococcus_neoformans_cds.fna
# 4                  saccharomyces_kudriavzevii_cds.fna
# ...                                               ...
# 2485  achaetomium_macrosporum_cbs_532_94_v1_0_cds.fna
# 2486           acarospora_strigata_cbs_132363_cds.fna
# 2487           absidia_padenii_nrrl_2977_v1_0_cds.fna
# 2488           absidia_caerulea_nrrl1315_v1_0_cds.fna
# 2489  abortiporus_biennis_cirm_brfm_1778_v1_0_cds.fna
#
#                                 original_name  \
# 0                    saccharomyces_cerevisiae
# 1                          fusarium_oxysporum
# 2                            candida_albicans
# 3                     cryptococcus_neoformans
# 4                  saccharomyces_kudriavzevii
# ...                                       ...
# 2485  achaetomium_macrosporum_cbs_532_94_v1_0
# 2486           acarospora_strigata_cbs_132363
# 2487           absidia_padenii_nrrl_2977_v1_0
# 2488           absidia_caerulea_nrrl1315_v1_0
# 2489  abortiporus_biennis_cirm_brfm_1778_v1_0
#
#                                                 cds_url  \
# 0     curl -H "Accept: application/zip" "https://api...
# 1     curl -H "Accept: application/zip" "https://api...
# 2     curl -H "Accept: application/zip" "https://api...
# 3     curl -H "Accept: application/zip" "https://api...
# 4     curl -H "Accept: application/zip" "https://api...
# ...                                                 ...
# 2485  curl -c cookies.txt -d "login=YOUR_JGI_USERNAM...
# 2486  curl -c cookies.txt -d "login=YOUR_JGI_USERNAM...
# 2487  curl -c cookies.txt -d "login=YOUR_JGI_USERNAM...
# 2488  curl -c cookies.txt -d "login=YOUR_JGI_USERNAM...
# 2489  curl -c cookies.txt -d "login=YOUR_JGI_USERNAM...
#
#                                              genome_url  \
# 0     curl -H "Accept: application/zip" "https://api...
# 1     curl -H "Accept: application/zip" "https://api...
# 2     curl -H "Accept: application/zip" "https://api...
# 3     curl -H "Accept: application/zip" "https://api...
# 4     curl -H "Accept: application/zip" "https://api...
# ...                                                 ...
# 2485  curl -c cookies.txt -d "login=YOUR_JGI_USERNAM...
# 2486  curl -c cookies.txt -d "login=YOUR_JGI_USERNAM...
# 2487  curl -c cookies.txt -d "login=YOUR_JGI_USERNAM...
# 2488  curl -c cookies.txt -d "login=YOUR_JGI_USERNAM...
# 2489  curl -c cookies.txt -d "login=YOUR_JGI_USERNAM...
#
#                                            proteome_url    source
# 0     curl -H "Accept: application/zip" "https://api...      NCBI
# 1     curl -H "Accept: application/zip" "https://api...      NCBI
# 2     curl -H "Accept: application/zip" "https://api...      NCBI
# 3     curl -H "Accept: application/zip" "https://api...      NCBI
# 4     curl -H "Accept: application/zip" "https://api...      NCBI
# ...                                                 ...       ...
# 2485  curl -c cookies.txt -d "login=YOUR_JGI_USERNAM...  MycoCosm
# 2486  curl -c cookies.txt -d "login=YOUR_JGI_USERNAM...  MycoCosm
# 2487  curl -c cookies.txt -d "login=YOUR_JGI_USERNAM...  MycoCosm
# 2488  curl -c cookies.txt -d "login=YOUR_JGI_USERNAM...  MycoCosm
# 2489  curl -c cookies.txt -d "login=YOUR_JGI_USERNAM...  MycoCosm
#
# [2490 rows x 8 columns]

# %%
fdb_dir = '../../data/FungiDB'
ncbi_dir = '../../data/NCBI'
ensembl_dir = '../../data/EnsemblFungi'
mycocosm_dir = '../../data/MycoCosm'

fdb = pd.read_csv(f'{fdb_dir}/fungidb_input_species.csv')
fdb['source'] = 'FungiDB'

ncbi = pd.read_csv(f'{ncbi_dir}/ncbi_input_species.csv')
ncbi['source'] = 'NCBI'

ensembl = pd.read_csv(f'{ensembl_dir}/ensembl_input_species.csv')
ensembl['source'] = 'EnsemblFungi'

mycocosm = pd.read_csv(f'{mycocosm_dir}/mycocosm_input_species.csv')
mycocosm['source'] = 'MycoCosm'

ncbi
# Out:
#                     species_name                        genome_file_name  \
# 0       saccharomyces_cerevisiae    saccharomyces_cerevisiae_genomic.fna
# 1             fusarium_oxysporum          fusarium_oxysporum_genomic.fna
# 2               candida_albicans            candida_albicans_genomic.fna
# 3        cryptococcus_neoformans     cryptococcus_neoformans_genomic.fna
# 4     saccharomyces_kudriavzevii  saccharomyces_kudriavzevii_genomic.fna
# ...                          ...                                     ...
# 1149     hyaloraphidium_curvatum     hyaloraphidium_curvatum_genomic.fna
# 1150        lachancea_fermentati        lachancea_fermentati_genomic.fna
# 1151    zygosaccharomyces_rouxii    zygosaccharomyces_rouxii_genomic.fna
# 1152        kluyveromyces_lactis        kluyveromyces_lactis_genomic.fna
# 1153   schizosaccharomyces_pombe   schizosaccharomyces_pombe_genomic.fna
#
#                            cds_file_name               original_name  \
# 0       saccharomyces_cerevisiae_cds.fna    saccharomyces_cerevisiae
# 1             fusarium_oxysporum_cds.fna          fusarium_oxysporum
# 2               candida_albicans_cds.fna            candida_albicans
# 3        cryptococcus_neoformans_cds.fna     cryptococcus_neoformans
# 4     saccharomyces_kudriavzevii_cds.fna  saccharomyces_kudriavzevii
# ...                                  ...                         ...
# 1149     hyaloraphidium_curvatum_cds.fna     hyaloraphidium_curvatum
# 1150        lachancea_fermentati_cds.fna        lachancea_fermentati
# 1151    zygosaccharomyces_rouxii_cds.fna    zygosaccharomyces_rouxii
# 1152        kluyveromyces_lactis_cds.fna        kluyveromyces_lactis
# 1153   schizosaccharomyces_pombe_cds.fna   schizosaccharomyces_pombe
#
#                                                 cds_url  \
# 0     curl -H "Accept: application/zip" "https://api...
# 1     curl -H "Accept: application/zip" "https://api...
# 2     curl -H "Accept: application/zip" "https://api...
# 3     curl -H "Accept: application/zip" "https://api...
# 4     curl -H "Accept: application/zip" "https://api...
# ...                                                 ...
# 1149  curl -H "Accept: application/zip" "https://api...
# 1150  curl -H "Accept: application/zip" "https://api...
# 1151  curl -H "Accept: application/zip" "https://api...
# 1152  curl -H "Accept: application/zip" "https://api...
# 1153  curl -H "Accept: application/zip" "https://api...
#
#                                              genome_url  \
# 0     curl -H "Accept: application/zip" "https://api...
# 1     curl -H "Accept: application/zip" "https://api...
# 2     curl -H "Accept: application/zip" "https://api...
# 3     curl -H "Accept: application/zip" "https://api...
# 4     curl -H "Accept: application/zip" "https://api...
# ...                                                 ...
# 1149  curl -H "Accept: application/zip" "https://api...
# 1150  curl -H "Accept: application/zip" "https://api...
# 1151  curl -H "Accept: application/zip" "https://api...
# 1152  curl -H "Accept: application/zip" "https://api...
# 1153  curl -H "Accept: application/zip" "https://api...
#
#                                            proteome_url source
# 0     curl -H "Accept: application/zip" "https://api...   NCBI
# 1     curl -H "Accept: application/zip" "https://api...   NCBI
# 2     curl -H "Accept: application/zip" "https://api...   NCBI
# 3     curl -H "Accept: application/zip" "https://api...   NCBI
# 4     curl -H "Accept: application/zip" "https://api...   NCBI
# ...                                                 ...    ...
# 1149  curl -H "Accept: application/zip" "https://api...   NCBI
# 1150  curl -H "Accept: application/zip" "https://api...   NCBI
# 1151  curl -H "Accept: application/zip" "https://api...   NCBI
# 1152  curl -H "Accept: application/zip" "https://api...   NCBI
# 1153  curl -H "Accept: application/zip" "https://api...   NCBI
#
# [1154 rows x 8 columns]

# %%
fdb = fdb.drop_duplicates(subset='species_name').reset_index(drop=True)
ncbi = ncbi.drop_duplicates(subset='species_name').reset_index(drop=True)
ensembl = ensembl.drop_duplicates(subset='species_name').reset_index(drop=True)
mycocosm = mycocosm.drop_duplicates(subset='species_name').reset_index(drop=True)

ncbi
# Out:
#                     species_name                        genome_file_name  \
# 0       saccharomyces_cerevisiae    saccharomyces_cerevisiae_genomic.fna
# 1             fusarium_oxysporum          fusarium_oxysporum_genomic.fna
# 2               candida_albicans            candida_albicans_genomic.fna
# 3        cryptococcus_neoformans     cryptococcus_neoformans_genomic.fna
# 4     saccharomyces_kudriavzevii  saccharomyces_kudriavzevii_genomic.fna
# ...                          ...                                     ...
# 1039     hyaloraphidium_curvatum     hyaloraphidium_curvatum_genomic.fna
# 1040        lachancea_fermentati        lachancea_fermentati_genomic.fna
# 1041    zygosaccharomyces_rouxii    zygosaccharomyces_rouxii_genomic.fna
# 1042        kluyveromyces_lactis        kluyveromyces_lactis_genomic.fna
# 1043   schizosaccharomyces_pombe   schizosaccharomyces_pombe_genomic.fna
#
#                            cds_file_name               original_name  \
# 0       saccharomyces_cerevisiae_cds.fna    saccharomyces_cerevisiae
# 1             fusarium_oxysporum_cds.fna          fusarium_oxysporum
# 2               candida_albicans_cds.fna            candida_albicans
# 3        cryptococcus_neoformans_cds.fna     cryptococcus_neoformans
# 4     saccharomyces_kudriavzevii_cds.fna  saccharomyces_kudriavzevii
# ...                                  ...                         ...
# 1039     hyaloraphidium_curvatum_cds.fna     hyaloraphidium_curvatum
# 1040        lachancea_fermentati_cds.fna        lachancea_fermentati
# 1041    zygosaccharomyces_rouxii_cds.fna    zygosaccharomyces_rouxii
# 1042        kluyveromyces_lactis_cds.fna        kluyveromyces_lactis
# 1043   schizosaccharomyces_pombe_cds.fna   schizosaccharomyces_pombe
#
#                                                 cds_url  \
# 0     curl -H "Accept: application/zip" "https://api...
# 1     curl -H "Accept: application/zip" "https://api...
# 2     curl -H "Accept: application/zip" "https://api...
# 3     curl -H "Accept: application/zip" "https://api...
# 4     curl -H "Accept: application/zip" "https://api...
# ...                                                 ...
# 1039  curl -H "Accept: application/zip" "https://api...
# 1040  curl -H "Accept: application/zip" "https://api...
# 1041  curl -H "Accept: application/zip" "https://api...
# 1042  curl -H "Accept: application/zip" "https://api...
# 1043  curl -H "Accept: application/zip" "https://api...
#
#                                              genome_url  \
# 0     curl -H "Accept: application/zip" "https://api...
# 1     curl -H "Accept: application/zip" "https://api...
# 2     curl -H "Accept: application/zip" "https://api...
# 3     curl -H "Accept: application/zip" "https://api...
# 4     curl -H "Accept: application/zip" "https://api...
# ...                                                 ...
# 1039  curl -H "Accept: application/zip" "https://api...
# 1040  curl -H "Accept: application/zip" "https://api...
# 1041  curl -H "Accept: application/zip" "https://api...
# 1042  curl -H "Accept: application/zip" "https://api...
# 1043  curl -H "Accept: application/zip" "https://api...
#
#                                            proteome_url source
# 0     curl -H "Accept: application/zip" "https://api...   NCBI
# 1     curl -H "Accept: application/zip" "https://api...   NCBI
# 2     curl -H "Accept: application/zip" "https://api...   NCBI
# 3     curl -H "Accept: application/zip" "https://api...   NCBI
# 4     curl -H "Accept: application/zip" "https://api...   NCBI
# ...                                                 ...    ...
# 1039  curl -H "Accept: application/zip" "https://api...   NCBI
# 1040  curl -H "Accept: application/zip" "https://api...   NCBI
# 1041  curl -H "Accept: application/zip" "https://api...   NCBI
# 1042  curl -H "Accept: application/zip" "https://api...   NCBI
# 1043  curl -H "Accept: application/zip" "https://api...   NCBI
#
# [1044 rows x 8 columns]

# %%
import matplotlib
import matplotlib.pyplot as plt
plt.rcParams['figure.dpi'] = 600
from venn import venn

fdb_col0 = set(fdb.iloc[:, 0])
ncbi_col0 = set(ncbi.iloc[:, 0])
mycocosm_col0 = set(mycocosm.iloc[:, 0])
ensembl_col0 = set(ensembl.iloc[:, 0])

all_four = {
    'FungiDB': fdb_col0,
    'NCBI': ncbi_col0,
    'MycoCosm': mycocosm_col0,
    'EnsemblFungi': ensembl_col0
}

plt = venn(all_four, cmap='plasma')
matplotlib.pyplot.savefig('venn.png')

# %%
import matplotlib.pyplot as plt
import numpy as np

source_counts = df['source'].value_counts()

cmap = plt.get_cmap('Spectral')
colors = [cmap(i) for i in np.linspace(0, 1, 8)]

plt.figure(figsize=(10, 6))
source_counts.plot(kind='pie', autopct='%1.1f%%', colors=colors)
plt.title('Distribution of Fungal Data Sources')
plt.ylabel('')
plt.show()

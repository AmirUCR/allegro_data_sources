# %%
import os
import pandas as pd

acc_to_name = {
    'NP_009673.1': 'LYS2',
    'NP_010290.3': 'TRP1',
    'NP_010851.1': 'CAN1',
    'NP_010893.3': 'URA3',
    'NP_012965.3': 'GAP1',
    'NP_013406.1': 'MET17',
    'NP_015387.1': 'FCY1',
}

num_files = len(os.listdir('outputs'))

ortho = pd.read_csv("Orthogroups.tsv", sep='\t').set_index('Orthogroup')
ortho
# Out:
#             aaosphaeria_arxii  \
# Orthogroup
# NP_009673.1    XP_033385684.1
# NP_010290.3    XP_033383113.1
# NP_010851.1    XP_033380291.1
# NP_010893.3    XP_033377334.1
# NP_012965.3    XP_033384385.1
# NP_013406.1    XP_033384847.1
# NP_015387.1    XP_033381876.1
#
#                      abortiporus_biennis_cirm_brfm_1778_v1_0  \
# Orthogroup
# NP_009673.1                        estExt_Genemark1.C_140103
# NP_010290.3                               fgenesh1_pg.42_#_2
# NP_010851.1                                    CE375199_1578
# NP_010893.3                                    CE208609_3043
# NP_012965.3                                       gm1.3849_g
# NP_013406.1  fgenesh1_kg.11_#_1125_#_TRINITY_DN3346_c0_g2_i1
# NP_015387.1                                       gm1.4072_g
#
#                               absidia_caerulea_nrrl1315_v1_0 absidia_glauca  \
# Orthogroup
# NP_009673.1                                      CE12943_874     SAM03069.1
# NP_010290.3    fgenesh1_kg.6_#_125_#_TRINITY_DN8644_c0_g1_i1     SAM04954.1
# NP_010851.1   fgenesh1_kg.1_#_516_#_TRINITY_DN15040_c0_g1_i1     SAL97032.1
# NP_010893.3  fgenesh1_kg.3_#_4138_#_TRINITY_DN10849_c0_g2_i1     SAM09098.1
# NP_012965.3   fgenesh1_kg.1_#_516_#_TRINITY_DN15040_c0_g1_i1     SAL97032.1
# NP_013406.1                      estExt_Genewise1.C_8_t20015     SAM07526.1
# NP_015387.1                                   e_gw1.4.1080.1      Not found
#
#                              absidia_padenii_nrrl_2977_v1_0  \
# Orthogroup
# NP_009673.1                      estExt_fgenesh1_pm.C_40086
# NP_010290.3  fgenesh1_kg.5_#_550_#_TRINITY_DN11505_c0_g1_i1
# NP_010851.1                                  CE122043_17865
# NP_010893.3                estExt_Genewise1Plus.C_10_t10205
# NP_012965.3                                  CE122043_17865
# NP_013406.1     fgenesh1_kg.71_#_8_#_TRINITY_DN247_c0_g1_i3
# NP_015387.1                                       Not found
#
#             absidia_repens_str_nrrl_1336 acaromyces_ingoldii  \
# Orthogroup
# NP_009673.1                     ORZ22283      XP_025381530.1
# NP_010290.3                     ORZ21646      XP_025377355.1
# NP_010851.1                     ORZ17096      XP_025375585.1
# NP_010893.3                     ORZ13950      XP_025375773.1
# NP_012965.3                     ORZ23243      XP_025378832.1
# NP_013406.1                     ORZ20271      XP_025380424.1
# NP_015387.1                     ORZ22366      XP_025378382.1
#
#             acarospora_aff_strigata acarospora_strigata_cbs_132363  \
# Orthogroup
# NP_009673.1            MCJ1362958.1                 AST1_002671-RA
# NP_010290.3            MCJ1367967.1                 AST1_005924-RA
# NP_010851.1            MCJ1367036.1                 AST1_006928-RA
# NP_010893.3            MCJ1367206.1                 AST1_007578-RA
# NP_012965.3            MCJ1365867.1                 AST1_007888-RA
# NP_013406.1            MCJ1366854.1                 AST1_001820-RA
# NP_015387.1               Not found                      Not found
#
#             acephala_macrosclerotiorum  ... zygoascus_hellenicus_y_7136_v1_0  \
# Orthogroup                              ...
# NP_009673.1               KAF8854761.1  ...                       gm1.1854_g
# NP_010290.3               KAF8863886.1  ...               fgenesh1_pg.2_#_89
# NP_010851.1               KAF8855414.1  ...                    e_gw1.3.212.1
# NP_010893.3               KAF8864864.1  ...                    e_gw1.5.105.1
# NP_012965.3               KAF8863372.1  ...                    e_gw1.4.523.1
# NP_013406.1               KAF8854398.1  ...    estExt_fgenesh1_pg.C_4_t10406
# NP_015387.1               KAF8863473.1  ...             fgenesh1_pg.1_#_1063
#
#             zygosaccharomyces_bailii zygosaccharomyces_mellis_str_ca_7  \
# Orthogroup
# NP_009673.1                 SJM87518                          GCE99155
# NP_010290.3                 SJM88532                          GCE99642
# NP_010851.1                 SJM88081                          GCF00950
# NP_010893.3                 SJM84548                          GCF00623
# NP_012965.3                 SJM85097                          GCE97503
# NP_013406.1                 SJM84500                          GCF00749
# NP_015387.1                 SJM87498                          GCE99139
#
#             zygosaccharomyces_parabailii_str_atcc_60483  \
# Orthogroup
# NP_009673.1                                    AQZ14213
# NP_010290.3                                    AQZ16007
# NP_010851.1                                    AQZ14092
# NP_010893.3                                    AQZ15485
# NP_012965.3                                    AQZ17213
# NP_013406.1                                    AQZ12340
# NP_015387.1                                    AQZ14233
#
#             zygosaccharomyces_rouxii zygotorulaspora_mrakii  \
# Orthogroup
# NP_009673.1           XP_002496359.1         XP_037142005.1
# NP_010290.3           XP_002494581.1         XP_037143622.1
# NP_010851.1           XP_002497925.1         XP_037141890.1
# NP_010893.3           XP_002499086.1         XP_037143064.1
# NP_012965.3           XP_002496596.1         XP_037146478.1
# NP_013406.1           XP_002498942.1         XP_037145227.1
# NP_015387.1           XP_002496341.1         XP_037142023.1
#
#             zymoseptoria_ardabiliae_stir04_1_1_1  \
# Orthogroup
# NP_009673.1              Za111_scaffold_573_0025
# NP_010290.3              Za111_scaffold_108_0106
# NP_010851.1              Za111_scaffold_235_0057
# NP_010893.3              Za111_scaffold_704_0046
# NP_012965.3              Za111_scaffold_802_0032
# NP_013406.1              Za111_scaffold_353_0159
# NP_015387.1             Za111_scaffold_1118_0007
#
#             zymoseptoria_brevis_str_zb18110  \
# Orthogroup
# NP_009673.1                        KJY00871
# NP_010290.3                        KJY01399
# NP_010851.1                        KJY00195
# NP_010893.3                        KJX95785
# NP_012965.3                        KJY02071
# NP_013406.1                        KJX94009
# NP_015387.1                        KJY02197
#
#             zymoseptoria_pseudotritici_stir04_2_2_1 zymoseptoria_tritici
# Orthogroup
# NP_009673.1               Zp221_scaffold_1700_00007       XP_003855519.1
# NP_010290.3                Zp221_scaffold_356_00026       XP_003856234.1
# NP_010851.1               Zp221_scaffold_1458_00001       XP_003852644.1
# NP_010893.3                Zp221_scaffold_599_00017       XP_003854922.1
# NP_012965.3                Zp221_scaffold_238_00028       XP_003851279.1
# NP_013406.1                Zp221_scaffold_901_00039       XP_003855480.1
# NP_015387.1                Zp221_scaffold_923_00022       XP_003853154.1
#
# [7 rows x 2481 columns]

# %%
ortho['yarrowia_lipolytica']
# Out:
# Orthogroup
# NP_009673.1    XP_503627.1
# NP_010290.3    XP_500614.1
# NP_010851.1    XP_501094.1
# NP_010893.3      Not found
# NP_012965.3    XP_500977.1
# NP_013406.1    XP_503263.1
# NP_015387.1    XP_505753.2
# Name: yarrowia_lipolytica, dtype: object

# %%
def find_cols_with_x_not_found(df, x):
    return df.columns[df.eq('Not found').sum() == x].tolist()

# Identify columns where only one row is "Not Found"
cols_with_one_not_found = find_cols_with_x_not_found(ortho, 1)
cols_with_two_not_found = find_cols_with_x_not_found(ortho, 2)
cols_with_three_not_found = find_cols_with_x_not_found(ortho, 3)
cols_with_four_not_found = find_cols_with_x_not_found(ortho, 4)
cols_with_five_not_found = find_cols_with_x_not_found(ortho, 5)
cols_with_six_not_found = find_cols_with_x_not_found(ortho, 6)
cols_with_seven_not_found = find_cols_with_x_not_found(ortho, 7)

print(f'{len(cols_with_one_not_found)} Species with one missing ortholog {cols_with_one_not_found}')
print(f'{len(cols_with_two_not_found)} Species with two missing ortholog {cols_with_two_not_found}')
print(f'{len(cols_with_three_not_found)} Species with three missing ortholog {cols_with_three_not_found}')
print(f'{len(cols_with_four_not_found)} Species with four missing ortholog {cols_with_four_not_found}')
print(f'{len(cols_with_five_not_found)} Species with five missing ortholog {cols_with_five_not_found}')
print(f'{len(cols_with_six_not_found)} Species with six missing ortholog {cols_with_six_not_found}')
print(f'{len(cols_with_seven_not_found)} Species with seven missing ortholog {cols_with_seven_not_found}')
# Out:
# 541 Species with one missing ortholog ['absidia_glauca', 'absidia_padenii_nrrl_2977_v1_0', 'acarospora_aff_strigata', 'acarospora_strigata_cbs_132363', 'achaetomium_macrosporum_cbs_532_94_v1_0', 'achaetomium_strumarium_cbs333_67_v1_0', 'acremonium_alcalophilum_v2_0', 'acremonium_chrysogenum_atcc_11550', 'acremonium_strictum_ds1bioay4a_v1_0', 'akanthomyces_lecanii', 'alternaria_ethzedia', 'amanita_inopinata', 'amylomyces_rouxii_nrrl_5866_v1_0', 'anaeromyces_robustus_str_s4', 'antarctomyces_sp_unipampa016_v1_0', 'anthracobia_sp_czu_v1_0', 'aphanocladium_album', 'arthroderma_benhamiae_cbs_112371', 'arthromyces_matolae', 'ascodesmis_nigricans', 'aspergillus_bisporus_cbs_707_71_v1_0', 'aspergillus_cejpii_cbs_157_66_v1_0', 'aspergillus_nanangensis', 'aspergillus_nidulans', 'aspergillus_penicilloides_cbs_540_65_v1_0', 'asterophora_parasitica', 'backusella_circina', 'batrachochytrium_dendrobatidis', 'batrachochytrium_salamandrivorans', 'beauveria_bassiana', 'beauveria_brongniartii_rcef_3172', 'blakeslea_trispora_nrrl_2456_v1_0', 'blastosporella_zonata', 'blumeria_graminis', 'blumeria_hordei', 'blyttiomyces_sp_jel0837', 'boletus_reticuloceps_br01', 'borealophlyctis_nickersoniae', 'botryobasidium_botryosum', 'bretziella_fagacearum_c519_v1_0', 'butyriboletus_roseoflavus_v1_0', 'caecomyces_churrovis_a_v1_0', 'calcarisporiella_thermophila_cbs_279_70', 'caloscypha_fulgens_atcc_42695_v1_0', 'canariomyces_arenarius_cbs_508_74_v1_0', 'candida_africana', 'candida_margitis', 'candida_membranifaciens_ist_626_v1_0', 'candida_oxycetoniae', 'cantharellus_anzutake_c23_v1_0', 'catenaria_anguillulae_pl171_v2_0', 'caulochytrium_protostelioides', 'ceraceosorus_bombacis', 'ceratobasidium_sp_392', 'ceratobasidium_theobromae_str_ct2', 'ceratocystis_platani_str_cfo', 'chaetocladium_brefeldii_nrrl_2343_metagenome_minimal_draft', 'chaetomidium_fimeti_cbs_168_71_v1_0', 'chaetomidium_leptoderma_cbs_538_74_v1_0', 'chaetomium_funicola_mpi_sdfr_at_0129_v1_0', 'chaetomium_globosum', 'chaetomium_olivicolor_cbs_102434', 'chaetomium_sp_mpi_cage_at_0009_v1_0', 'chaetomium_thermophilum_var_thermophilum_dsm_1495', 'choanephora_cucurbitarum_str_kus_f28377', 'chroogomphus_vinicolor_ca002_v1_0', 'chytridiales_sp_jel_0842', 'chytridium_lagenaria_arg66_v1_0', 'chytriomyces_cf_hyalinus_jel632', 'chytriomyces_confervae', 'chytriomyces_hyalinus_jel632_v1_0', 'chytriomyces_sp_mp71', 'circinella_minor', 'circinella_umbellata_nrrl1351_v1_0', 'cladochytrium_replicatum_jel_714_v1_0', 'cladorrhinum_bulbillosum_dj3_v1_0', 'cladorrhinum_microsclerotigenum_cbs_290_75_v1_0', 'cladorrhinum_samala_psn324_v1_0', 'cladorrhinum_sp_psn332_v1_0', 'clonostachys_chloroleuca', 'clonostachys_rhizophaga', 'clonostachys_sp_corfu0009_v1_0', 'coemansia_sp_rsa_25', 'cokeromyces_recurvatus_nrrl_2243_v1_0', 'conidiobolus_coronatus', 'conidiobolus_thromboides_fsu_785_v1_0', 'coprinopsis_sclerotiger_v1_0', 'cordyceps_fumosorosea', 'cordyceps_javanica', 'cordyceps_militaris', 'cordyceps_sp_rao_2017', 'corollospora_maritima_cbs_119819_v2_0', 'corynascella_inaequalis_cbs_284_82_v1_0', 'corynascus_novoguineensis_cbs_359_72_v1_0', 'corynascus_sepedonium_atcc9787', 'cryptococcus_terreus_61_443_v1_0', 'cyathus_stercoreus_nk_82_v1_0', 'cylindrodendrum_hubeiense', 'dactylonectria_estremocensis_mpi_cage_at_0021_v1_0', 'dactylonectria_macrodidyma_mpi_cage_at_0147_v1_0', 'dentipellis_fragilis', 'dichomitus_squalens', 'digitatispora_marina_008cd1_1_v1_0', 'dimargaris_cristalligena', 'dioszegia_cryoxerica_ant03_071_v1_0', 'dioszegia_hungarica_pdd_24b_2', 'dispira_simplex', 'diversispora_epigaea', 'drechmeria_coniospora', 'drechslerella_stenobrocha', 'emergomyces_africanus', 'emergomyces_pasteurianus', 'emericellopsis_atlantica', 'emericellopsis_cladophorae', 'emericellopsis_sp_ts7_v1_0', 'emmonsia_sp_cac_2015a_str_cbs_136260', 'emydomyces_testavorans', 'endocarpon_pallidulum_enpa', 'endocarpon_pusillum', 'endogone_sp_flas_f59071', 'entoleuca_mammata_cfl468_v1_0', 'entomophthora_muscae', 'entomortierella_beljakovae', 'entom ...
# 31 Species with two missing ortholog ['allomyces_arbusculus', 'allomyces_macrogynus', 'alternaria_gaisen_bmp2338', 'bifiguratus_adelaidae', 'blastocladiella_britannica', 'blyttiomyces_helicus', 'entomophaga_maimaiga_arsef_7190_v1_0', 'epichloe_festucae', 'gaertneriomyces_semiglobifer_barr_43_v1_0', 'gelatoporia_subvermispora', 'gymnopus_luxurians_fd_317_m1', 'hemileia_vastatrix', 'hyaloraphidium_curvatum', 'jimgerdemannia_lactiflua_osc166217', 'leucoagaricus_gongylophorus_ac12', 'malassezia_sympodialis', 'moniliophthora_perniciosa_fa553', 'olpidium_bornovanus_ubc_f19785', 'penicillium_decumbens', 'piromyces_sp_e2', 'rhizoclosmatium_hyalinum', 'rhizopus_stolonifer', 'scedosporium_apiospermum', 'scytalidium_sp_3c', 'syncephalis_pseudoplumigaleata', 'thermothelomyces_hinnuleus_atcc_52474', 'tolypocladium_paradoxum', 'tulasnella_calospora', 'verticillium_alfalfae', 'zancudomyces_culisetae', 'zoophthora_radicans_atcc_208865_v1_0']
# 1 Species with three missing ortholog ['gorgonomyces_haynaldii_mp57_v1_0']
# 3 Species with four missing ortholog ['aspergillus_ustus', 'paramicrosporidium_saccamoebae', 'pneumocystis_jirovecii']
# 9 Species with five missing ortholog ['amphiamblys_sp_wsbs2006', 'antonospora_locustae_hm_2013', 'pneumocystis_canis', 'pneumocystis_carinii', 'pneumocystis_murina', 'pneumocystis_sp_macacae_', 'pneumocystis_wakefieldiae', 'rozella_allomycis', 'thelohania_contejeani']
# 4 Species with six missing ortholog ['encephalitozoon_intestinalis', 'mitosporidium_daphniae_ugp3', 'nematocida_homosporus', 'ordospora_colligata_oc4']
# 37 Species with seven missing ortholog ['anncaliia_algerae', 'cucumispora_dikerogammari', 'dictyocoela_muelleri', 'dictyocoela_roeselum', 'edhazardia_aedis', 'encephalitozoon_cuniculi', 'encephalitozoon_hellem', 'encephalitozoon_romaleae', 'enterocytozoon_bieneusi_h348', 'enterocytozoon_hepatopenaei_str_th1', 'enteropsectra_breve', 'enterospora_canceri_str_gb1', 'hamiltosporidium_magnivora', 'hamiltosporidium_tvaerminnensis', 'hepatospora_eriocheir', 'nematocida_ausubeli', 'nematocida_displodere', 'nematocida_major', 'nematocida_minor', 'nematocida_parisii', 'nematocida_sp_awrm78', 'nosema_apis_brl_01', 'nosema_bombycis', 'nosema_ceranae', 'nosema_granulosis', 'ordospora_pajunii_micg_i_from_lake_walsh_micg_i_fungal_bin_annotation', 'pancytospora_epiphaga', 'pancytospora_philotis', 'pneumocystis_oryctolagi', 'pseudoloma_neurophilia_str_mk1', 'spraguea_lophii_42_110', 'talaromyces_borbonicus_cbs_141340_', 'trachipleistophora_hominis', 'tubulinosema_ratisbonensis', 'vairimorpha_apis', 'vavraia_culicis', 'vittaforma_corneae']

# %%
ortho['anncaliia_algerae']
# Out:
# Orthogroup
# NP_009673.1    Not found
# NP_010290.3    Not found
# NP_010851.1    Not found
# NP_010893.3    Not found
# NP_012965.3    Not found
# NP_013406.1    Not found
# NP_015387.1    Not found
# Name: anncaliia_algerae, dtype: object

# %%
ortho['absidia_glauca']
# Out:
# Orthogroup
# NP_009673.1    SAM03069.1
# NP_010290.3    SAM04954.1
# NP_010851.1    SAL97032.1
# NP_010893.3    SAM09098.1
# NP_012965.3    SAL97032.1
# NP_013406.1    SAM07526.1
# NP_015387.1     Not found
# Name: absidia_glauca, dtype: object

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.dpi'] = 600

# Compute count of "Not found" entries for each column
not_found_counts = ortho.eq('Not found').sum()

# Count columns with x "Not Found"
counts = [sum(not_found_counts == i) for i in range(1, 8)]

# Adding counts as text above each bar
for i, count in enumerate(counts):
    plt.text(i + 1, count + 0.5, str(count), ha='center', va='bottom')

# Plotting
plt.bar(range(1, 8), counts, color='orange', alpha=0.7)
plt.xlabel('Number of missing orthologs')
plt.ylabel('Number of species')
plt.title('Histogram of missing orthologs per species')
plt.xticks(range(1, 8))
plt.yticks(range(0, 700, 100))
plt.grid(alpha=0.1, linestyle='--')
plt.show()

# %%
counts
# Out:
# [541, 31, 1, 3, 9, 4, 37]

# %%
d = {
    'NP_009673.1': [],  # LYS2
    'NP_010290.3': [],  # TRP1
    'NP_010851.1': [],  # CAN1
    'NP_010893.3': [],  # URA3
    'NP_012965.3': [],  # GAP1
    'NP_013406.1': [],  # MET17
    'NP_015387.1': []   # FCY1
}

missing_in = {
    'NP_009673.1': [],  # LYS2
    'NP_010290.3': [],  # TRP1
    'NP_010851.1': [],  # CAN1
    'NP_010893.3': [],  # URA3
    'NP_012965.3': [],  # GAP1
    'NP_013406.1': [],  # MET17
    'NP_015387.1': []   # FCY1
}

for species in [e for e in ortho.columns.tolist()]:
    df = pd.read_csv(f'outputs/{species}.tsv', sep='\t', names=['scer_gene', 'ortho', 'identity', 'a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i'])

    for gene, l in d.items():
        if ortho[species][gene] != 'Not found' and gene in df['scer_gene'].values:
            d[gene].append(df[df['scer_gene'] == gene]['identity'].values[0])
        else:
            missing_in[gene].append(species)
            
total_missing = 0
for gene, missing_in_species in missing_in.items():
    length = len(missing_in_species)
    print(f'Gene {gene} {acc_to_name[gene]} is missing its ortholog in {length} species')
    total_missing += length

print(f'Total missing orthologs {total_missing}')
# Out:
# Gene NP_009673.1 LYS2 is missing its ortholog in 48 species
# Gene NP_010290.3 TRP1 is missing its ortholog in 86 species
# Gene NP_010851.1 CAN1 is missing its ortholog in 54 species
# Gene NP_010893.3 URA3 is missing its ortholog in 80 species
# Gene NP_012965.3 GAP1 is missing its ortholog in 72 species
# Gene NP_013406.1 MET17 is missing its ortholog in 45 species
# Gene NP_015387.1 FCY1 is missing its ortholog in 561 species
# Total missing orthologs 946

# %% [markdown]
# # Sensitivity analysis

# %% [markdown]
# Find out the ranges of ortholog identity for best hits in each species

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.dpi'] = 300
import numpy as np

keys = list(d.keys())
values = list(d.values())

# Setting up the subplots
fig, axs = plt.subplots(nrows=len(keys), figsize=(10, 30))

# Looping through each key and generating histograms with fixed bins and displaying counts above each bar
for i, (key, value) in enumerate(d.items()):
    # Plot histogram
    counts, bins, patches = axs[i].hist(value, bins=np.arange(0, 100, 10), alpha=0.7, color='orange')
    
    # Add counts above each bar
    for count, bin, patch in zip(counts, bins, patches):
        height = patch.get_height()
        axs[i].text(bin + 5, height + 0.2, str(int(count)), ha='center', va='bottom', fontsize=9, color='black')
    
    axs[i].set_title(f"{acc_to_name[key]} Identity of Best Ortholog per Species")
    axs[i].set_ylabel("Species Frequency")
    axs[i].set_xlabel("Ortholog Identity Percentage")
    axs[i].set_xlim(0, 100)
    axs[i].set_ylim(0, 2500)
    axs[i].set_xticks(np.arange(0, 101, 10))
    axs[i].grid(alpha=0.1, linestyle='--')

# Adjusting layout to prevent overlap
plt.tight_layout()
plt.show()

# %%
for gene in d.keys():
    low_quality = len([e for e in d[gene] if e >= 0 and e < 30])
    length = len(d[gene])

    print(f'Gene {gene} has {low_quality}/{length} low quality (< 30% identity) orthologs')
# Out:
# Gene NP_009673.1 has 25/2433 low quality (< 30% identity) orthologs
# Gene NP_010290.3 has 182/2395 low quality (< 30% identity) orthologs
# Gene NP_010851.1 has 31/2427 low quality (< 30% identity) orthologs
# Gene NP_010893.3 has 9/2401 low quality (< 30% identity) orthologs
# Gene NP_012965.3 has 13/2409 low quality (< 30% identity) orthologs
# Gene NP_013406.1 has 71/2436 low quality (< 30% identity) orthologs
# Gene NP_015387.1 has 184/1920 low quality (< 30% identity) orthologs

# %% [markdown]
# ## Mark orthologs with low (< 30%) identity as "Not found"

# %%
ortho_high_identity = ortho.copy(deep=True)

for species in ortho.columns.tolist():
    df = pd.read_csv(f'outputs/{species}.tsv', sep='\t', names=['scer_gene', 'ortho', 'identity', 'a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i'])
    low_identities = df[df['identity'] < 30]['scer_gene'].tolist()
    ortho_high_identity.loc[ortho_high_identity.index.isin(low_identities), species] = 'Not found'

ortho_high_identity
# Out:
#             aaosphaeria_arxii  \
# Orthogroup
# NP_009673.1    XP_033385684.1
# NP_010290.3    XP_033383113.1
# NP_010851.1    XP_033380291.1
# NP_010893.3    XP_033377334.1
# NP_012965.3    XP_033384385.1
# NP_013406.1    XP_033384847.1
# NP_015387.1    XP_033381876.1
#
#                      abortiporus_biennis_cirm_brfm_1778_v1_0  \
# Orthogroup
# NP_009673.1                        estExt_Genemark1.C_140103
# NP_010290.3                               fgenesh1_pg.42_#_2
# NP_010851.1                                    CE375199_1578
# NP_010893.3                                    CE208609_3043
# NP_012965.3                                       gm1.3849_g
# NP_013406.1  fgenesh1_kg.11_#_1125_#_TRINITY_DN3346_c0_g2_i1
# NP_015387.1                                       gm1.4072_g
#
#                               absidia_caerulea_nrrl1315_v1_0 absidia_glauca  \
# Orthogroup
# NP_009673.1                                      CE12943_874     SAM03069.1
# NP_010290.3    fgenesh1_kg.6_#_125_#_TRINITY_DN8644_c0_g1_i1     SAM04954.1
# NP_010851.1   fgenesh1_kg.1_#_516_#_TRINITY_DN15040_c0_g1_i1     SAL97032.1
# NP_010893.3  fgenesh1_kg.3_#_4138_#_TRINITY_DN10849_c0_g2_i1     SAM09098.1
# NP_012965.3   fgenesh1_kg.1_#_516_#_TRINITY_DN15040_c0_g1_i1     SAL97032.1
# NP_013406.1                      estExt_Genewise1.C_8_t20015     SAM07526.1
# NP_015387.1                                        Not found      Not found
#
#                              absidia_padenii_nrrl_2977_v1_0  \
# Orthogroup
# NP_009673.1                      estExt_fgenesh1_pm.C_40086
# NP_010290.3  fgenesh1_kg.5_#_550_#_TRINITY_DN11505_c0_g1_i1
# NP_010851.1                                  CE122043_17865
# NP_010893.3                estExt_Genewise1Plus.C_10_t10205
# NP_012965.3                                  CE122043_17865
# NP_013406.1     fgenesh1_kg.71_#_8_#_TRINITY_DN247_c0_g1_i3
# NP_015387.1                                       Not found
#
#             absidia_repens_str_nrrl_1336 acaromyces_ingoldii  \
# Orthogroup
# NP_009673.1                     ORZ22283      XP_025381530.1
# NP_010290.3                     ORZ21646      XP_025377355.1
# NP_010851.1                     ORZ17096      XP_025375585.1
# NP_010893.3                     ORZ13950      XP_025375773.1
# NP_012965.3                     ORZ23243      XP_025378832.1
# NP_013406.1                     ORZ20271      XP_025380424.1
# NP_015387.1                    Not found      XP_025378382.1
#
#             acarospora_aff_strigata acarospora_strigata_cbs_132363  \
# Orthogroup
# NP_009673.1            MCJ1362958.1                 AST1_002671-RA
# NP_010290.3            MCJ1367967.1                 AST1_005924-RA
# NP_010851.1            MCJ1367036.1                 AST1_006928-RA
# NP_010893.3            MCJ1367206.1                      Not found
# NP_012965.3            MCJ1365867.1                 AST1_007888-RA
# NP_013406.1            MCJ1366854.1                 AST1_001820-RA
# NP_015387.1               Not found                      Not found
#
#             acephala_macrosclerotiorum  ... zygoascus_hellenicus_y_7136_v1_0  \
# Orthogroup                              ...
# NP_009673.1               KAF8854761.1  ...                       gm1.1854_g
# NP_010290.3               KAF8863886.1  ...               fgenesh1_pg.2_#_89
# NP_010851.1               KAF8855414.1  ...                    e_gw1.3.212.1
# NP_010893.3               KAF8864864.1  ...                    e_gw1.5.105.1
# NP_012965.3               KAF8863372.1  ...                    e_gw1.4.523.1
# NP_013406.1               KAF8854398.1  ...    estExt_fgenesh1_pg.C_4_t10406
# NP_015387.1               KAF8863473.1  ...             fgenesh1_pg.1_#_1063
#
#             zygosaccharomyces_bailii zygosaccharomyces_mellis_str_ca_7  \
# Orthogroup
# NP_009673.1                 SJM87518                          GCE99155
# NP_010290.3                 SJM88532                          GCE99642
# NP_010851.1                 SJM88081                          GCF00950
# NP_010893.3                 SJM84548                          GCF00623
# NP_012965.3                 SJM85097                          GCE97503
# NP_013406.1                 SJM84500                          GCF00749
# NP_015387.1                 SJM87498                          GCE99139
#
#             zygosaccharomyces_parabailii_str_atcc_60483  \
# Orthogroup
# NP_009673.1                                    AQZ14213
# NP_010290.3                                    AQZ16007
# NP_010851.1                                    AQZ14092
# NP_010893.3                                    AQZ15485
# NP_012965.3                                    AQZ17213
# NP_013406.1                                    AQZ12340
# NP_015387.1                                    AQZ14233
#
#             zygosaccharomyces_rouxii zygotorulaspora_mrakii  \
# Orthogroup
# NP_009673.1           XP_002496359.1         XP_037142005.1
# NP_010290.3           XP_002494581.1         XP_037143622.1
# NP_010851.1           XP_002497925.1         XP_037141890.1
# NP_010893.3           XP_002499086.1         XP_037143064.1
# NP_012965.3           XP_002496596.1         XP_037146478.1
# NP_013406.1           XP_002498942.1         XP_037145227.1
# NP_015387.1           XP_002496341.1         XP_037142023.1
#
#             zymoseptoria_ardabiliae_stir04_1_1_1  \
# Orthogroup
# NP_009673.1              Za111_scaffold_573_0025
# NP_010290.3              Za111_scaffold_108_0106
# NP_010851.1              Za111_scaffold_235_0057
# NP_010893.3              Za111_scaffold_704_0046
# NP_012965.3              Za111_scaffold_802_0032
# NP_013406.1              Za111_scaffold_353_0159
# NP_015387.1             Za111_scaffold_1118_0007
#
#             zymoseptoria_brevis_str_zb18110  \
# Orthogroup
# NP_009673.1                        KJY00871
# NP_010290.3                        KJY01399
# NP_010851.1                        KJY00195
# NP_010893.3                        KJX95785
# NP_012965.3                        KJY02071
# NP_013406.1                        KJX94009
# NP_015387.1                        KJY02197
#
#             zymoseptoria_pseudotritici_stir04_2_2_1 zymoseptoria_tritici
# Orthogroup
# NP_009673.1               Zp221_scaffold_1700_00007       XP_003855519.1
# NP_010290.3                Zp221_scaffold_356_00026       XP_003856234.1
# NP_010851.1               Zp221_scaffold_1458_00001       XP_003852644.1
# NP_010893.3                Zp221_scaffold_599_00017       XP_003854922.1
# NP_012965.3                Zp221_scaffold_238_00028       XP_003851279.1
# NP_013406.1                Zp221_scaffold_901_00039       XP_003855480.1
# NP_015387.1                Zp221_scaffold_923_00022       XP_003853154.1
#
# [7 rows x 2481 columns]

# %%
# Compute count of "Not found" entries for each column
not_found_counts = ortho_high_identity.eq('Not found').sum()

# Count columns with x "Not Found"
counts = [sum(not_found_counts == i) for i in range(1, 8)]

# Adding counts as text above each bar
for i, count in enumerate(counts):
    plt.text(i + 1, count + 0.5, str(count), ha='center', va='bottom')

# Plotting
plt.bar(range(1, 8), counts, color='orange', alpha=0.7)
plt.xlabel('Number of missing orthologs')
plt.ylabel('Number of species')
plt.title('Histogram of missing orthologs per species')
plt.xticks(range(1, 8))
plt.yticks(range(0, 801, 100))
plt.grid(alpha=0.1, linestyle='--')
plt.show()

# %%
counts
# Out:
# [747, 120, 37, 3, 6, 4, 43]

# %% [markdown]
# ## Remove species with 6 or 7 missing orthologs

# %%
cols_with_six_not_found = find_cols_with_x_not_found(ortho_high_identity, 6)
cols_with_seven_not_found = find_cols_with_x_not_found(ortho_high_identity, 7)

len(cols_with_six_not_found) + len(cols_with_seven_not_found)
# Out:
# 47

# %%
ortho_high_identity.drop(cols_with_six_not_found, axis=1, inplace=True)
ortho_high_identity.drop(cols_with_seven_not_found, axis=1, inplace=True)

ortho_high_identity
# Out:
#             aaosphaeria_arxii  \
# Orthogroup
# NP_009673.1    XP_033385684.1
# NP_010290.3    XP_033383113.1
# NP_010851.1    XP_033380291.1
# NP_010893.3    XP_033377334.1
# NP_012965.3    XP_033384385.1
# NP_013406.1    XP_033384847.1
# NP_015387.1    XP_033381876.1
#
#                      abortiporus_biennis_cirm_brfm_1778_v1_0  \
# Orthogroup
# NP_009673.1                        estExt_Genemark1.C_140103
# NP_010290.3                               fgenesh1_pg.42_#_2
# NP_010851.1                                    CE375199_1578
# NP_010893.3                                    CE208609_3043
# NP_012965.3                                       gm1.3849_g
# NP_013406.1  fgenesh1_kg.11_#_1125_#_TRINITY_DN3346_c0_g2_i1
# NP_015387.1                                       gm1.4072_g
#
#                               absidia_caerulea_nrrl1315_v1_0 absidia_glauca  \
# Orthogroup
# NP_009673.1                                      CE12943_874     SAM03069.1
# NP_010290.3    fgenesh1_kg.6_#_125_#_TRINITY_DN8644_c0_g1_i1     SAM04954.1
# NP_010851.1   fgenesh1_kg.1_#_516_#_TRINITY_DN15040_c0_g1_i1     SAL97032.1
# NP_010893.3  fgenesh1_kg.3_#_4138_#_TRINITY_DN10849_c0_g2_i1     SAM09098.1
# NP_012965.3   fgenesh1_kg.1_#_516_#_TRINITY_DN15040_c0_g1_i1     SAL97032.1
# NP_013406.1                      estExt_Genewise1.C_8_t20015     SAM07526.1
# NP_015387.1                                        Not found      Not found
#
#                              absidia_padenii_nrrl_2977_v1_0  \
# Orthogroup
# NP_009673.1                      estExt_fgenesh1_pm.C_40086
# NP_010290.3  fgenesh1_kg.5_#_550_#_TRINITY_DN11505_c0_g1_i1
# NP_010851.1                                  CE122043_17865
# NP_010893.3                estExt_Genewise1Plus.C_10_t10205
# NP_012965.3                                  CE122043_17865
# NP_013406.1     fgenesh1_kg.71_#_8_#_TRINITY_DN247_c0_g1_i3
# NP_015387.1                                       Not found
#
#             absidia_repens_str_nrrl_1336 acaromyces_ingoldii  \
# Orthogroup
# NP_009673.1                     ORZ22283      XP_025381530.1
# NP_010290.3                     ORZ21646      XP_025377355.1
# NP_010851.1                     ORZ17096      XP_025375585.1
# NP_010893.3                     ORZ13950      XP_025375773.1
# NP_012965.3                     ORZ23243      XP_025378832.1
# NP_013406.1                     ORZ20271      XP_025380424.1
# NP_015387.1                    Not found      XP_025378382.1
#
#             acarospora_aff_strigata acarospora_strigata_cbs_132363  \
# Orthogroup
# NP_009673.1            MCJ1362958.1                 AST1_002671-RA
# NP_010290.3            MCJ1367967.1                 AST1_005924-RA
# NP_010851.1            MCJ1367036.1                 AST1_006928-RA
# NP_010893.3            MCJ1367206.1                      Not found
# NP_012965.3            MCJ1365867.1                 AST1_007888-RA
# NP_013406.1            MCJ1366854.1                 AST1_001820-RA
# NP_015387.1               Not found                      Not found
#
#             acephala_macrosclerotiorum  ... zygoascus_hellenicus_y_7136_v1_0  \
# Orthogroup                              ...
# NP_009673.1               KAF8854761.1  ...                       gm1.1854_g
# NP_010290.3               KAF8863886.1  ...               fgenesh1_pg.2_#_89
# NP_010851.1               KAF8855414.1  ...                    e_gw1.3.212.1
# NP_010893.3               KAF8864864.1  ...                    e_gw1.5.105.1
# NP_012965.3               KAF8863372.1  ...                    e_gw1.4.523.1
# NP_013406.1               KAF8854398.1  ...    estExt_fgenesh1_pg.C_4_t10406
# NP_015387.1               KAF8863473.1  ...             fgenesh1_pg.1_#_1063
#
#             zygosaccharomyces_bailii zygosaccharomyces_mellis_str_ca_7  \
# Orthogroup
# NP_009673.1                 SJM87518                          GCE99155
# NP_010290.3                 SJM88532                          GCE99642
# NP_010851.1                 SJM88081                          GCF00950
# NP_010893.3                 SJM84548                          GCF00623
# NP_012965.3                 SJM85097                          GCE97503
# NP_013406.1                 SJM84500                          GCF00749
# NP_015387.1                 SJM87498                          GCE99139
#
#             zygosaccharomyces_parabailii_str_atcc_60483  \
# Orthogroup
# NP_009673.1                                    AQZ14213
# NP_010290.3                                    AQZ16007
# NP_010851.1                                    AQZ14092
# NP_010893.3                                    AQZ15485
# NP_012965.3                                    AQZ17213
# NP_013406.1                                    AQZ12340
# NP_015387.1                                    AQZ14233
#
#             zygosaccharomyces_rouxii zygotorulaspora_mrakii  \
# Orthogroup
# NP_009673.1           XP_002496359.1         XP_037142005.1
# NP_010290.3           XP_002494581.1         XP_037143622.1
# NP_010851.1           XP_002497925.1         XP_037141890.1
# NP_010893.3           XP_002499086.1         XP_037143064.1
# NP_012965.3           XP_002496596.1         XP_037146478.1
# NP_013406.1           XP_002498942.1         XP_037145227.1
# NP_015387.1           XP_002496341.1         XP_037142023.1
#
#             zymoseptoria_ardabiliae_stir04_1_1_1  \
# Orthogroup
# NP_009673.1              Za111_scaffold_573_0025
# NP_010290.3              Za111_scaffold_108_0106
# NP_010851.1              Za111_scaffold_235_0057
# NP_010893.3              Za111_scaffold_704_0046
# NP_012965.3              Za111_scaffold_802_0032
# NP_013406.1              Za111_scaffold_353_0159
# NP_015387.1             Za111_scaffold_1118_0007
#
#             zymoseptoria_brevis_str_zb18110  \
# Orthogroup
# NP_009673.1                        KJY00871
# NP_010290.3                        KJY01399
# NP_010851.1                        KJY00195
# NP_010893.3                        KJX95785
# NP_012965.3                        KJY02071
# NP_013406.1                        KJX94009
# NP_015387.1                        KJY02197
#
#             zymoseptoria_pseudotritici_stir04_2_2_1 zymoseptoria_tritici
# Orthogroup
# NP_009673.1               Zp221_scaffold_1700_00007       XP_003855519.1
# NP_010290.3                Zp221_scaffold_356_00026       XP_003856234.1
# NP_010851.1               Zp221_scaffold_1458_00001       XP_003852644.1
# NP_010893.3                Zp221_scaffold_599_00017       XP_003854922.1
# NP_012965.3                Zp221_scaffold_238_00028       XP_003851279.1
# NP_013406.1                Zp221_scaffold_901_00039       XP_003855480.1
# NP_015387.1                Zp221_scaffold_923_00022       XP_003853154.1
#
# [7 rows x 2434 columns]

# %%
ortho_high_identity = ortho_high_identity.reset_index()
ortho_high_identity.to_csv('Orthogroups_HI.tsv', sep='\t', index=False)

# %%
ortho_high_identity = pd.read_csv('Orthogroups_HI.tsv', sep='\t').set_index('Orthogroup')

d = {
    'NP_009673.1': [],  # LYS2
    'NP_010290.3': [],  # TRP1
    'NP_010851.1': [],  # CAN1
    'NP_010893.3': [],  # URA3
    'NP_012965.3': [],  # GAP1
    'NP_013406.1': [],  # MET17
    'NP_015387.1': []   # FCY1
}

missing_in = {
    'NP_009673.1': [],  # LYS2
    'NP_010290.3': [],  # TRP1
    'NP_010851.1': [],  # CAN1
    'NP_010893.3': [],  # URA3
    'NP_012965.3': [],  # GAP1
    'NP_013406.1': [],  # MET17
    'NP_015387.1': []   # FCY1
}

for species in [e for e in ortho_high_identity.columns.tolist()]:
    df = pd.read_csv(f'outputs/{species}.tsv', sep='\t', names=['scer_gene', 'ortho', 'identity', 'a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i'])

    for gene, l in d.items():
        if ortho_high_identity[species][gene] != 'Not found' and gene in df['scer_gene'].values:
            d[gene].append(df[df['scer_gene'] == gene]['identity'].values[0])
        else:
            missing_in[gene].append(species)
            
total_missing = 0
for gene, missing_in_species in missing_in.items():
    length = len(missing_in_species)
    print(f'Gene {gene} {acc_to_name[gene]} is missing its ortholog in {length} species')
    total_missing += length

print(f'Total missing orthologs {total_missing}')
# Out:
# Gene NP_009673.1 LYS2 is missing its ortholog in 26 species
# Gene NP_010290.3 TRP1 is missing its ortholog in 221 species
# Gene NP_010851.1 CAN1 is missing its ortholog in 38 species
# Gene NP_010893.3 URA3 is missing its ortholog in 44 species
# Gene NP_012965.3 GAP1 is missing its ortholog in 38 species
# Gene NP_013406.1 MET17 is missing its ortholog in 70 species
# Gene NP_015387.1 FCY1 is missing its ortholog in 699 species
# Total missing orthologs 1136

# %%
len(d['NP_009673.1'])
# Out:
# 2408

# %%
ortho_high_identity.loc['NP_009673.1'].eq('Not found').sum()
# Out:
# 26

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.dpi'] = 300
import numpy as np

keys = list(d.keys())
values = list(d.values())

# Setting up the subplots
fig, axs = plt.subplots(nrows=len(keys), figsize=(10, 30))

# Looping through each key and generating histograms with fixed bins and displaying counts above each bar
for i, (key, value) in enumerate(d.items()):
    # Plot histogram
    counts, bins, patches = axs[i].hist(value, bins=np.arange(0, 110, 10), alpha=0.7, color='orange')
    
    # Add counts above each bar
    for count, bin, patch in zip(counts, bins, patches):
        height = patch.get_height()
        axs[i].text(bin + 5, height + 0.2, str(int(count)), ha='center', va='bottom', fontsize=9, color='black')
    
    axs[i].set_title(f"{acc_to_name[key]} Identity of Best Ortholog per Species")
    axs[i].set_ylabel("Species Frequency")
    axs[i].set_xlabel("Ortholog Identity Percentage")
    axs[i].set_xlim(0, 100)
    axs[i].set_ylim(0, 2500)
    axs[i].set_xticks(np.arange(0, 101, 10))
    axs[i].grid(alpha=0.1, linestyle='--')

# Adjusting layout to prevent overlap
plt.tight_layout()
plt.show()

# %%
ortho_high_identity = ortho_high_identity.reset_index()
ortho_high_identity
# Out:
#     Orthogroup aaosphaeria_arxii  \
# 0  NP_009673.1    XP_033385684.1
# 1  NP_010290.3    XP_033383113.1
# 2  NP_010851.1    XP_033380291.1
# 3  NP_010893.3    XP_033377334.1
# 4  NP_012965.3    XP_033384385.1
# 5  NP_013406.1    XP_033384847.1
# 6  NP_015387.1    XP_033381876.1
#
#            abortiporus_biennis_cirm_brfm_1778_v1_0  \
# 0                        estExt_Genemark1.C_140103
# 1                               fgenesh1_pg.42_#_2
# 2                                    CE375199_1578
# 3                                    CE208609_3043
# 4                                       gm1.3849_g
# 5  fgenesh1_kg.11_#_1125_#_TRINITY_DN3346_c0_g2_i1
# 6                                       gm1.4072_g
#
#                     absidia_caerulea_nrrl1315_v1_0 absidia_glauca  \
# 0                                      CE12943_874     SAM03069.1
# 1    fgenesh1_kg.6_#_125_#_TRINITY_DN8644_c0_g1_i1     SAM04954.1
# 2   fgenesh1_kg.1_#_516_#_TRINITY_DN15040_c0_g1_i1     SAL97032.1
# 3  fgenesh1_kg.3_#_4138_#_TRINITY_DN10849_c0_g2_i1     SAM09098.1
# 4   fgenesh1_kg.1_#_516_#_TRINITY_DN15040_c0_g1_i1     SAL97032.1
# 5                      estExt_Genewise1.C_8_t20015     SAM07526.1
# 6                                        Not found      Not found
#
#                    absidia_padenii_nrrl_2977_v1_0  \
# 0                      estExt_fgenesh1_pm.C_40086
# 1  fgenesh1_kg.5_#_550_#_TRINITY_DN11505_c0_g1_i1
# 2                                  CE122043_17865
# 3                estExt_Genewise1Plus.C_10_t10205
# 4                                  CE122043_17865
# 5     fgenesh1_kg.71_#_8_#_TRINITY_DN247_c0_g1_i3
# 6                                       Not found
#
#   absidia_repens_str_nrrl_1336 acaromyces_ingoldii acarospora_aff_strigata  \
# 0                     ORZ22283      XP_025381530.1            MCJ1362958.1
# 1                     ORZ21646      XP_025377355.1            MCJ1367967.1
# 2                     ORZ17096      XP_025375585.1            MCJ1367036.1
# 3                     ORZ13950      XP_025375773.1            MCJ1367206.1
# 4                     ORZ23243      XP_025378832.1            MCJ1365867.1
# 5                     ORZ20271      XP_025380424.1            MCJ1366854.1
# 6                    Not found      XP_025378382.1               Not found
#
#   acarospora_strigata_cbs_132363  ... zygoascus_hellenicus_y_7136_v1_0  \
# 0                 AST1_002671-RA  ...                       gm1.1854_g
# 1                 AST1_005924-RA  ...               fgenesh1_pg.2_#_89
# 2                 AST1_006928-RA  ...                    e_gw1.3.212.1
# 3                      Not found  ...                    e_gw1.5.105.1
# 4                 AST1_007888-RA  ...                    e_gw1.4.523.1
# 5                 AST1_001820-RA  ...    estExt_fgenesh1_pg.C_4_t10406
# 6                      Not found  ...             fgenesh1_pg.1_#_1063
#
#   zygosaccharomyces_bailii zygosaccharomyces_mellis_str_ca_7  \
# 0                 SJM87518                          GCE99155
# 1                 SJM88532                          GCE99642
# 2                 SJM88081                          GCF00950
# 3                 SJM84548                          GCF00623
# 4                 SJM85097                          GCE97503
# 5                 SJM84500                          GCF00749
# 6                 SJM87498                          GCE99139
#
#   zygosaccharomyces_parabailii_str_atcc_60483 zygosaccharomyces_rouxii  \
# 0                                    AQZ14213           XP_002496359.1
# 1                                    AQZ16007           XP_002494581.1
# 2                                    AQZ14092           XP_002497925.1
# 3                                    AQZ15485           XP_002499086.1
# 4                                    AQZ17213           XP_002496596.1
# 5                                    AQZ12340           XP_002498942.1
# 6                                    AQZ14233           XP_002496341.1
#
#   zygotorulaspora_mrakii zymoseptoria_ardabiliae_stir04_1_1_1  \
# 0         XP_037142005.1              Za111_scaffold_573_0025
# 1         XP_037143622.1              Za111_scaffold_108_0106
# 2         XP_037141890.1              Za111_scaffold_235_0057
# 3         XP_037143064.1              Za111_scaffold_704_0046
# 4         XP_037146478.1              Za111_scaffold_802_0032
# 5         XP_037145227.1              Za111_scaffold_353_0159
# 6         XP_037142023.1             Za111_scaffold_1118_0007
#
#   zymoseptoria_brevis_str_zb18110 zymoseptoria_pseudotritici_stir04_2_2_1  \
# 0                        KJY00871               Zp221_scaffold_1700_00007
# 1                        KJY01399                Zp221_scaffold_356_00026
# 2                        KJY00195               Zp221_scaffold_1458_00001
# 3                        KJX95785                Zp221_scaffold_599_00017
# 4                        KJY02071                Zp221_scaffold_238_00028
# 5                        KJX94009                Zp221_scaffold_901_00039
# 6                        KJY02197                Zp221_scaffold_923_00022
#
#   zymoseptoria_tritici
# 0       XP_003855519.1
# 1       XP_003856234.1
# 2       XP_003852644.1
# 3       XP_003854922.1
# 4       XP_003851279.1
# 5       XP_003855480.1
# 6       XP_003853154.1
#
# [7 rows x 2435 columns]

# %%
import shutil
import os

if not os.path.exists('../../../data/fourdbs_concat/removed'):
    os.makedirs('../../../data/fourdbs_concat/removed/cds')
    os.makedirs('../../../data/fourdbs_concat/removed/genomes')
    os.makedirs('../../../data/fourdbs_concat/removed/proteomes')

input_species = pd.read_csv('../../../data/fourdbs_concat/fourdbs_input_species.csv')
ortho_species = ortho_high_identity.columns.tolist()

removed_species = input_species[~input_species['original_name'].isin(ortho_species)].reset_index(drop=True)
removed_species.to_csv('../../../data/fourdbs_concat/removed/removed_species.csv', index=False)

input_species = input_species[input_species['original_name'].isin(ortho_species)].reset_index(drop=True)
input_species.to_csv('../../../data/fourdbs_concat/fourdbs_hi_input_species.csv', index=False)

input_species
# Out:
#                     species_name  \
# 0       saccharomyces_cerevisiae
# 1             fusarium_oxysporum
# 2               candida_albicans
# 3        cryptococcus_neoformans
# 4     saccharomyces_kudriavzevii
# ...                          ...
# 2429     achaetomium_macrosporum
# 2430         acarospora_strigata
# 2431             absidia_padenii
# 2432            absidia_caerulea
# 2433         abortiporus_biennis
#
#                                        genome_file_name  \
# 0                  saccharomyces_cerevisiae_genomic.fna
# 1                        fusarium_oxysporum_genomic.fna
# 2                          candida_albicans_genomic.fna
# 3                   cryptococcus_neoformans_genomic.fna
# 4                saccharomyces_kudriavzevii_genomic.fna
# ...                                                 ...
# 2429  achaetomium_macrosporum_cbs_532_94_v1_0_genomi...
# 2430         acarospora_strigata_cbs_132363_genomic.fna
# 2431         absidia_padenii_nrrl_2977_v1_0_genomic.fna
# 2432         absidia_caerulea_nrrl1315_v1_0_genomic.fna
# 2433  abortiporus_biennis_cirm_brfm_1778_v1_0_genomi...
#
#                                         cds_file_name  \
# 0                    saccharomyces_cerevisiae_cds.fna
# 1                          fusarium_oxysporum_cds.fna
# 2                            candida_albicans_cds.fna
# 3                     cryptococcus_neoformans_cds.fna
# 4                  saccharomyces_kudriavzevii_cds.fna
# ...                                               ...
# 2429  achaetomium_macrosporum_cbs_532_94_v1_0_cds.fna
# 2430           acarospora_strigata_cbs_132363_cds.fna
# 2431           absidia_padenii_nrrl_2977_v1_0_cds.fna
# 2432           absidia_caerulea_nrrl1315_v1_0_cds.fna
# 2433  abortiporus_biennis_cirm_brfm_1778_v1_0_cds.fna
#
#                                 original_name  \
# 0                    saccharomyces_cerevisiae
# 1                          fusarium_oxysporum
# 2                            candida_albicans
# 3                     cryptococcus_neoformans
# 4                  saccharomyces_kudriavzevii
# ...                                       ...
# 2429  achaetomium_macrosporum_cbs_532_94_v1_0
# 2430           acarospora_strigata_cbs_132363
# 2431           absidia_padenii_nrrl_2977_v1_0
# 2432           absidia_caerulea_nrrl1315_v1_0
# 2433  abortiporus_biennis_cirm_brfm_1778_v1_0
#
#                                                 cds_url  \
# 0     curl -H "Accept: application/zip" "https://api...
# 1     curl -H "Accept: application/zip" "https://api...
# 2     curl -H "Accept: application/zip" "https://api...
# 3     curl -H "Accept: application/zip" "https://api...
# 4     curl -H "Accept: application/zip" "https://api...
# ...                                                 ...
# 2429  curl -c cookies.txt -d "login=YOUR_JGI_USERNAM...
# 2430  curl -c cookies.txt -d "login=YOUR_JGI_USERNAM...
# 2431  curl -c cookies.txt -d "login=YOUR_JGI_USERNAM...
# 2432  curl -c cookies.txt -d "login=YOUR_JGI_USERNAM...
# 2433  curl -c cookies.txt -d "login=YOUR_JGI_USERNAM...
#
#                                              genome_url  \
# 0     curl -H "Accept: application/zip" "https://api...
# 1     curl -H "Accept: application/zip" "https://api...
# 2     curl -H "Accept: application/zip" "https://api...
# 3     curl -H "Accept: application/zip" "https://api...
# 4     curl -H "Accept: application/zip" "https://api...
# ...                                                 ...
# 2429  curl -c cookies.txt -d "login=YOUR_JGI_USERNAM...
# 2430  curl -c cookies.txt -d "login=YOUR_JGI_USERNAM...
# 2431  curl -c cookies.txt -d "login=YOUR_JGI_USERNAM...
# 2432  curl -c cookies.txt -d "login=YOUR_JGI_USERNAM...
# 2433  curl -c cookies.txt -d "login=YOUR_JGI_USERNAM...
#
#                                            proteome_url    source
# 0     curl -H "Accept: application/zip" "https://api...      NCBI
# 1     curl -H "Accept: application/zip" "https://api...      NCBI
# 2     curl -H "Accept: application/zip" "https://api...      NCBI
# 3     curl -H "Accept: application/zip" "https://api...      NCBI
# 4     curl -H "Accept: application/zip" "https://api...      NCBI
# ...                                                 ...       ...
# 2429  curl -c cookies.txt -d "login=YOUR_JGI_USERNAM...  MycoCosm
# 2430  curl -c cookies.txt -d "login=YOUR_JGI_USERNAM...  MycoCosm
# 2431  curl -c cookies.txt -d "login=YOUR_JGI_USERNAM...  MycoCosm
# 2432  curl -c cookies.txt -d "login=YOUR_JGI_USERNAM...  MycoCosm
# 2433  curl -c cookies.txt -d "login=YOUR_JGI_USERNAM...  MycoCosm
#
# [2434 rows x 8 columns]

# %%
for idx, row in removed_species.iterrows():
    if os.path.exists(f"../../../data/fourdbs_concat/cds/{row['cds_file_name']}"):
        shutil.move(f"../../../data/fourdbs_concat/cds/{row['cds_file_name']}", f"../../../data/fourdbs_concat/removed/cds/{row['cds_file_name']}")

    if os.path.exists(f"../../../data/fourdbs_concat/genomes/{row['genome_file_name']}"):
        shutil.move(f"../../../data/fourdbs_concat/genomes/{row['genome_file_name']}", f"../../../data/fourdbs_concat/removed/genomes/{row['genome_file_name']}")

    if os.path.exists(f"../../../data/fourdbs_concat/proteomes/{row['original_name']}.faa"):
        shutil.move(f"../../../data/fourdbs_concat/proteomes/{row['original_name']}.faa", f"../../../data/fourdbs_concat/removed/proteomes/{row['original_name']}.faa")

# %%
import matplotlib.pyplot as plt
import numpy as np

source_counts = input_species['source'].value_counts()

cmap = plt.get_cmap('Spectral')
colors = [cmap(i) for i in np.linspace(0, 1, 8)]

# Function to display both raw counts and percentages
def func(pct, allvals):
    absolute = int(round(pct / 100.0 * sum(allvals)))
    return "{:.1f}% ({:d})".format(pct, absolute)

# Plotting the pie chart with shadow, white text color, and both raw counts and percentages
plt.figure(figsize=(10, 6))
source_counts.plot(kind='pie', autopct=lambda p: func(p, source_counts), colors=colors)
plt.title('Distribution of Finalized Sources')
plt.ylabel('')  # Removing the default y-label
plt.show()

# %%
input_species['source'].value_counts()
# Out:
# MycoCosm        1178
# NCBI            1010
# EnsemblFungi     202
# FungiDB           53
# Name: source, dtype: int64
